# %% [markdown]
# # Data Visualization

# %% [markdown]
# **Data Visualization gives us the faster way of understanding the data**
#
#
# **Exploratory Data Analysis (EDA)**
#
#
#     1) Univariate Analysis - Where we are taking only one variable and analysing that, for example using the histogram we can create the data distribution age of customers here we can use the box plot. For categorial variable for gender we can use the count plots which can help us to understand how many customers are male and female
#
#     2) Bivariate Analysis - Where we are taking only two variables and analysing that. It can be numerical and numerical (scatter plot) For example the relationship between house price and the area of the house. It can be categorical and numerical Gender and the sales.
#
#     3) Multivariate Analysis - Where we are taking more than two variables, it can be all numericals, it can be mix of categoricals and numericals.

# %%
import os 
os.chdir(r'E:\SmartCube\End to End Code')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **https://matplotlib.org/**
#
# **https://seaborn.pydata.org/**

# %%
dataset_loan = pd.read_csv('Python_Credit_Risk_XTrain.csv')

# %%
dataset_loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset_loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
for group, data in dataset_loan.groupby('Property_Area'):
    print(group,data['ApplicantIncome'].mean())
# Out:
# Rural 5554.083798882682
# Semiurban 5292.261802575107
# Urban 5398.247524752475

# %%
plt.figure(figsize=(10,3))
for group, data in dataset_loan.groupby('Property_Area'):
    plt.bar(group,data['ApplicantIncome'].mean())
    plt.xlabel('Property Area')
    plt.ylabel('Avg. Applicant Income')
    plt.title('Property Area vs. Avg. Applicant Income')

# %%
plt.figure(figsize=(10,3))
for group, data in dataset_loan.groupby('Property_Area'):
    plt.barh(group,data['ApplicantIncome'].mean())
    plt.xlabel('Property Area')
    plt.ylabel('Avg. Applicant Income')
    plt.title('Property Area vs. Avg. Applicant Income')

# %%
prop_area = dict()
for i in set(dataset_loan['Property_Area']):
    prop_area[i] = dataset_loan[dataset_loan['Property_Area']==i].Property_Area.count()

# %%
prop_area
# Out:
# {'Rural': 179, 'Semiurban': 233, 'Urban': 202}

# %%
plt.figure(figsize=(5,3))
plt.bar(prop_area.keys(), prop_area.values())
plt.xlabel('Property Area')
plt.ylabel('Count of Property Area')
plt.title('Property Area Count')
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.pie(prop_area.values(), labels=prop_area.keys())
plt.title('Property Area Count')
plt.show()

# %%
plt.hist(dataset_loan.ApplicantIncome)
plt.show()

# %%
plt.scatter(dataset_loan['ApplicantIncome'], dataset_loan['CoapplicantIncome'])
plt.xlabel('Applicant Income')
plt.ylabel('Coapplicant Income')
plt.xlim((0,20000))
plt.ylim((0,10000))
plt.show()

# %%
type(dataset_loan['ApplicantIncome'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Seaborn

# %%
sns.countplot(data=dataset_loan,x='Gender', hue='Loan_Status')
plt.show()

# %%
sns.countplot(data=dataset_loan,x='Married', hue='Loan_Status')
plt.show()

# %%
dataset_loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(data=dataset_loan,x='Credit_History', hue='Loan_Status')
plt.show()

# %%
sns.lmplot(data=dataset_loan,x='ApplicantIncome',y='CoapplicantIncome', hue='Loan_Status',fit_reg=False)
plt.show()

# %%
sns.lmplot(data=dataset_loan,x='ApplicantIncome',y='CoapplicantIncome', hue='Loan_Status',col='Property_Area',fit_reg=False)
plt.show()

# %%
car_sales = pd.read_csv('E:\Courses\Python Basics to Advanced\Car_sales.csv')

# %%
sns.distplot(car_sales['Fuel efficiency'],kde=False)
plt.show()
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25160\2666817560.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(car_sales['Fuel efficiency'],kde=False)

# %%
car_sales[car_sales['Fuel efficiency']>40]
# Out:
#    Manufacturer              Model  Sales in thousands  4-year resale value  \
# 61    Chevrolet  Metro                          21.855                 5.16
#
#    Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 61    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 61   62.6   149.4        1.895           10.3             45.0     13-Apr-14

# %%
sns.lmplot(data=car_sales, x='Fuel capacity', y='Fuel efficiency',fit_reg=False,hue='Vehicle type')

# %%
sns.jointplot(data=car_sales,x='Fuel capacity', y='Fuel efficiency')

# %%
sns.countplot(data=car_sales,y='Vehicle type')
# Out:
# <Axes: xlabel='count', ylabel='Vehicle type'>

# %%
sns.barplot(data=car_sales, y='Vehicle type', x='4-year resale value')
# Out:
# <Axes: xlabel='4-year resale value', ylabel='Vehicle type'>

# %%
sns.stripplot(data=car_sales, y='Vehicle type',x='4-year resale value')
# Out:
# <Axes: xlabel='4-year resale value', ylabel='Vehicle type'>

# %%
sns.pairplot(car_sales[['Horsepower', 'Fuel efficiency', 'Fuel capacity', 'Curb weight', 'Vehicle type']],hue='Vehicle type')

# %%
sns.heatmap(car_sales[['Horsepower', 'Fuel efficiency', 'Fuel capacity', 'Curb weight', 'Vehicle type']].corr(),annot=True)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25160\2222016076.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(car_sales[['Horsepower', 'Fuel efficiency', 'Fuel capacity', 'Curb weight', 'Vehicle type']].corr(),annot=True)
# <Axes: >

# %%
sns.boxplot(data=car_sales,y='Vehicle type', x='Fuel efficiency')
# Out:
# <Axes: xlabel='Fuel efficiency', ylabel='Vehicle type'>

# %%
sns.violinplot(data=car_sales,y='Vehicle type', x='Fuel efficiency')
# Out:
# <Axes: xlabel='Fuel efficiency', ylabel='Vehicle type'>

# %%
import pygwalker as pyg

# %%
gwalker = pyg.walk(car_sales)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:660px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     left:0;
#     top:56px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-0">
#         <div class="tabs">
#
#         </div>
#     </div>
# </body>
# </html>
